# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from math import sqrt

# Google Drive 연동
from google.colab import drive
drive.mount('/content/gdrive')

# 데이터 불러오기
data = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/bigdata/city_people_sum.csv")

# 날짜 정보를 활용하여 연도와 월을 하나의 날짜 형식으로 변환
data['date'] = pd.to_datetime(data[['year', 'month']].assign(day=1))

# 도시별로 모델 학습 및 예측 수행
cities = data['city'].unique()
predictions = {}
accuracies = []

for city in cities:
    city_data = data[data['city'] == city]

    # 데이터가 충분하지 않은 경우, 학습 및 예측을 수행하지 않음
    if len(city_data) < 100:
        print(f"City: {city} - Not enough data for training (Less than 100 samples)")
        continue

    # 2009년 12월부터 2022년 12월까지의 데이터로 학습
    train_data = city_data[(city_data['date'] >= '2009-12-01') & (city_data['date'] <= '2019-12-01')]

    # X (날짜)와 y (여행객 수) 데이터 설정
    X_train = train_data[['year', 'month']]
    y_train = train_data['people']

    # Linear Regression 모델 생성 및 학습
    model = LinearRegression()
    model.fit(X_train, y_train)

    # 2023년 1월부터 7월까지의 여행객 수 예측을 위한 데이터 준비
    forecast_dates = pd.date_range(start='2023-01-01', end='2023-07-01', freq='MS')
    forecast_data = pd.DataFrame({'year': forecast_dates.year, 'month': forecast_dates.month})

    # 2023년 1월부터 7월까지의 여행객 수 예측
    forecast = model.predict(forecast_data)
    forecast = np.where(forecast < 0, 0, forecast)

    # 각 도시와 월 간의 상관관계 계산
correlations = data.groupby(['city', 'month'])['people'].corr(data['people']).reset_index()

for _, row in correlations.iterrows():
    city = row['city']
    month = row['month']
    correlation_value = row['people']

    city_data = data[data['city'] == city]

    # 데이터가 충분하지 않은 경우, 학습 및 예측을 수행하지 않음
    if len(city_data) < 12:
        print(f"City: {city} - Not enough data for training (Less than 12 samples)")
        continue

    # 2009년 12월부터 2022년 12월까지의 데이터로 학습
    train_data = city_data[(city_data['date'] >= '2009-12-01') & (city_data['date'] <= '2022-12-01')]

    # X (날짜)와 y (여행객 수) 데이터 설정
    X_train = train_data[['year', 'month']]
    y_train = train_data['people']

    # Linear Regression 모델 생성 및 학습
    model = LinearRegression()
    model.fit(X_train, y_train)

    # 2023년 1월부터 7월까지의 여행객 수 예측을 위한 데이터 준비
    forecast_dates = pd.date_range(start='2023-01-01', end='2023-07-01', freq='MS')
    forecast_data = pd.DataFrame({'year': forecast_dates.year, 'month': forecast_dates.month})

    # 2023년 1월부터 7월까지의 여행객 수 예측
    forecast = model.predict(forecast_data)
    forecast = np.where(forecast < 0, 0, forecast)

    # 상관관계 값에 따라 예측값 조정
    if correlation_value > 0:
        forecast += correlation_value  # 양의 상관관계인 경우 예측값 더하기
    elif correlation_value < 0:
        forecast -= correlation_value  # 음의 상관관계인 경우 예측값 빼기

    predictions[city] = forecast

    # 해당 도시의 실제 데이터 가져오기
    actual_data = city_data[(city_data['date'] >= '2023-01-01') & (city_data['date'] <= '2023-07-01')]

    # 실제 데이터가 없는 경우를 확인
    if actual_data.empty:
        print(f"City: {city} - No actual data available for this period.")
        continue

    # 예측값과 실제값 출력
    print(f"City: {city}")

    # 예측된 여행객 수와 실제 여행객 수를 저장할 리스트 초기화
    predicted_values = []
    actual_values = []

    for date, forecast_value in zip(forecast_dates, forecast):
        # 실제 데이터에서 해당 날짜의 데이터 찾기
        actual_data_row = actual_data[actual_data['date'] == date]

        if not actual_data_row.empty:
            actual_value = actual_data_row['people'].values[0]
            if actual_value == 0:
              continue
            print(f"Date: {date.strftime('%Y-%m')}, Predicted People: {forecast_value:.2f}, Actual People: {actual_value:.2f}")

            # 예측된 여행객 수와 실제 여행객 수를 리스트에 추가
            predicted_values.append(forecast_value)
            actual_values.append(actual_value)

    if len(predicted_values) == 0:
        continue

    # RMSE 계산 및 정확도 계산
    if np.mean(actual_values) != 0:
        rmse = sqrt(mean_squared_error(actual_values, predicted_values))
        accuracy = 100 * (1 - rmse / np.mean(actual_values))
        accuracies.append(accuracy)

mean_accuracy = np.mean(accuracies)
print(f"Mean Accuracy for All Cities: {mean_accuracy:.2f}%")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# City: ISA 공군기지 - Not enough data for training (Less than 100 samples)
# City: 갈릴레오갈릴레이 - Not enough data for training (Less than 100 samples)
# City: 고베 - Not enough data for training (Less than 100 samples)
# City: 고찌 - Not enough data for training (Less than 100 samples)
# City: 고테버그 - Not enough data for training (Less than 100 samples)
# City: 골드코스트 - Not enough data for training (Less than 100 samples)
# City: 과달라하라 - Not enough data for training (Less than 100 samples)
# City: 구시로 - Not enough data for training (Less than 100 samples)
# City: 구이양 - Not enough data for training (Less than 100 samples)
# City: 구즈베이 - Not enough data for training (Less than 100 samples)
# City: 그린빌-스파르탄버그 - Not enough data for training (Less than 100 samples)
# City: 김포 - Not enough data for training (Less than 100 samples)
# City: 김해 - Not enough data for training (Less than 100 samples)
# City: 껀터 - Not enough data for training (Less than 100 samples)
# City: 끄라비 - Not enough data for training (Less than 100 samples)
# City: 나쉬빌 - Not enough data for training (Less than 100 samples)
# City: 나이로비 - Not enough data for training (Less than 100 samples)
# City: 나트랑 - Not enough data for training (Less than 100 samples)
# City: 나트랑캄란 - Not enough data for training (Less than 100 samples)
# City: 난링 - Not enough data for training (Less than 100 samples)
# City: 난창 - Not enough data for training (Less than 100 samples)
# City: 난퉁 - Not enough data for training (Less than 100 samples)
# City: 네피도 - Not enough data for training (Less than 100 samples)
# City: 노팅햄이스트미들랜드 - Not enough data for training (Less than 100 samples)
# City: 누메아 - Not enough data for training (Less than 100 samples)
# City: 누크스 - Not enough data for training (Less than 100 samples)
# City: 뉴버그 - Not enough data for training (Less than 100 samples)
# City: 니쯔네바토브스크 - Not enough data for training (Less than 100 samples)
# City: 닝보 - Not enough data for training (Less than 100 samples)
# City: 다싱국제공항 - Not enough data for training (Less than 100 samples)
# City: 다윈 - Not enough data for training (Less than 100 samples)
# City: 다카 - Not enough data for training (Less than 100 samples)
# City: 단동 - Not enough data for training (Less than 100 samples)
# City: 달랏 - Not enough data for training (Less than 100 samples)
# City: 담맘 - Not enough data for training (Less than 100 samples)
# City: 대구 - Not enough data for training (Less than 100 samples)
# City: 대퉁 - Not enough data for training (Less than 100 samples)
# City: 더반 - Not enough data for training (Less than 100 samples)
# City: 덜루스 - Not enough data for training (Less than 100 samples)
# City: 덴버 - Not enough data for training (Less than 100 samples)
# City: 델바이오 - Not enough data for training (Less than 100 samples)
# City: 도버체스올드 - Not enough data for training (Less than 100 samples)
# City: 도쿠시마 - Not enough data for training (Less than 100 samples)
# City: 돈무앙 - Not enough data for training (Less than 100 samples)
# City: 두브로브니크 - Not enough data for training (Less than 100 samples)
# City: 뒤셀도르프 - Not enough data for training (Less than 100 samples)
# City: 듀산베 - Not enough data for training (Less than 100 samples)
# City: 따이쭝 - Not enough data for training (Less than 100 samples)
# City: 뚜성루브르뚜르 - Not enough data for training (Less than 100 samples)
# City: 라고스 - Not enough data for training (Less than 100 samples)
# City: 라용 - Not enough data for training (Less than 100 samples)
# City: 라크셀브 - Not enough data for training (Less than 100 samples)
# City: 라호르 - Not enough data for training (Less than 100 samples)
# City: 란저우 - Not enough data for training (Less than 100 samples)
# City: 랑카위 - Not enough data for training (Less than 100 samples)
# City: 램스타인 - Not enough data for training (Less than 100 samples)
# City: 런던개트윅 - Not enough data for training (Less than 100 samples)
# City: 로그 밸리 인터네셔널 메드퍼드 - Not enough data for training (Less than 100 samples)
# City: 로스토크 - Not enough data for training (Less than 100 samples)
# City: 로타 나발 스테이션 - Not enough data for training (Less than 100 samples)
# City: 롬복 - Not enough data for training (Less than 100 samples)
# City: 루앙프라방 - Not enough data for training (Less than 100 samples)
# City: 루이즈빌 - Not enough data for training (Less than 100 samples)
# City: 룰레오 - Not enough data for training (Less than 100 samples)
# City: 리가 - Not enough data for training (Less than 100 samples)
# City: 리스본 - Not enough data for training (Less than 100 samples)
# City: 리야드 - Not enough data for training (Less than 100 samples)
# City: 리에쥬 비어셋 - Not enough data for training (Less than 100 samples)
# City: 리오데자네이로 - Not enough data for training (Less than 100 samples)
# City: 리용 - Not enough data for training (Less than 100 samples)
# City: 리지앙 - Not enough data for training (Less than 100 samples)
# City: 리켄백 - Not enough data for training (Less than 100 samples)
# City: 린이 - Not enough data for training (Less than 100 samples)
# City: 마가단 - Not enough data for training (Less than 100 samples)
# City: 마나도 - Not enough data for training (Less than 100 samples)
# City: 마나스 - Not enough data for training (Less than 100 samples)
# City: 마나우스-에두아르도고메즈 - Not enough data for training (Less than 100 samples)
# City: 마라나 - Not enough data for training (Less than 100 samples)
# City: 마르세이유-프로방스 - Not enough data for training (Less than 100 samples)
# City: 마르켈쿤하마차도 - Not enough data for training (Less than 100 samples)
# City: 마리 - Not enough data for training (Less than 100 samples)
# City: 마쓰모또 - Not enough data for training (Less than 100 samples)
# City: 마자리-샤리프 - Not enough data for training (Less than 100 samples)
# City: 만달레이 - Not enough data for training (Less than 100 samples)
# City: 만저우리 - Not enough data for training (Less than 100 samples)
# City: 맥과이어공군기지 - Not enough data for training (Less than 100 samples)
# City: 맥코넬 공군기지 - Not enough data for training (Less than 100 samples)
# City: 맨체스터 - Not enough data for training (Less than 100 samples)
# City: 메만베츠 - Not enough data for training (Less than 100 samples)
# City: 멕시코 - Not enough data for training (Less than 100 samples)
# City: 멜버른 툴라마린 - Not enough data for training (Less than 100 samples)
# City: 몬테레이 - Not enough data for training (Less than 100 samples)
# City: 몬트리얼 - Not enough data for training (Less than 100 samples)
# City: 몰타 - Not enough data for training (Less than 100 samples)
# City: 몸바사모이 - Not enough data for training (Less than 100 samples)
# City: 뮐루즈 - Not enough data for training (Less than 100 samples)
# City: 미네아폴리스 - Not enough data for training (Less than 100 samples)
# City: 미야코 - Not enough data for training (Less than 100 samples)
# City: 미자와 - Not enough data for training (Less than 100 samples)
# City: 미티가 - Not enough data for training (Less than 100 samples)
# City: 미해군항공기지 - Not enough data for training (Less than 100 samples)
# City: 민스크 - Not enough data for training (Less than 100 samples)
# City: 바그다드 - Not enough data for training (Less than 100 samples)
# City: 바그람공군기지 - Not enough data for training (Less than 100 samples)
# City: 바라나시 - Not enough data for training (Less than 100 samples)
# City: 바레인 - Not enough data for training (Less than 100 samples)
# City: 바로셀로나 - Not enough data for training (Less than 100 samples)
# City: 바오터우 - Not enough data for training (Less than 100 samples)
# City: 바콜로드 - Not enough data for training (Less than 100 samples)
# City: 바탐 - Not enough data for training (Less than 100 samples)
# City: 반다르세리베가완 - Not enough data for training (Less than 100 samples)
# City: 발릭파판 - Not enough data for training (Less than 100 samples)
# City: 뱅갈로 - Not enough data for training (Less than 100 samples)
# City: 번돈 - Not enough data for training (Less than 100 samples)
# City: 베니스 - Not enough data for training (Less than 100 samples)
# City: 베를린-쇤펠트 - Not enough data for training (Less than 100 samples)
# City: 베이루트 - Not enough data for training (Less than 100 samples)
# City: 벤하지-베니아 - Not enough data for training (Less than 100 samples)
# City: 보르도 - Not enough data for training (Less than 100 samples)
# City: 보리스필 - Not enough data for training (Less than 100 samples)
# City: 보스톤 - Not enough data for training (Less than 100 samples)
# City: 보잉필드 - Not enough data for training (Less than 100 samples)
# City: 부다페스트 - Not enough data for training (Less than 100 samples)
# City: 부쿠레슈티 - Not enough data for training (Less than 100 samples)
# City: 부하라 - Not enough data for training (Less than 100 samples)
# City: 불가스 - Not enough data for training (Less than 100 samples)
# City: 브로츠와프 - Not enough data for training (Less than 100 samples)
# City: 블라고베첸스크 - Not enough data for training (Less than 100 samples)
# City: 빅스육군비행장 - Not enough data for training (Less than 100 samples)
# City: 빅터빌 - Not enough data for training (Less than 100 samples)
# City: 빌란드 - Not enough data for training (Less than 100 samples)
# City: 사가 - Not enough data for training (Less than 100 samples)
# City: 사베타 - Not enough data for training (Less than 100 samples)
# City: 사비하 - Not enough data for training (Less than 100 samples)
# City: 산토우 - Not enough data for training (Less than 100 samples)
# City: 산티아고 - Not enough data for training (Less than 100 samples)
# City: 산티아고데콤포스텔라 - Not enough data for training (Less than 100 samples)
# City: 산호세 - Not enough data for training (Less than 100 samples)
# City: 상파울로 - Not enough data for training (Less than 100 samples)
# City: 샤논 - Not enough data for training (Less than 100 samples)
# City: 샤니아 - Not enough data for training (Less than 100 samples)
# City: 샤론스 - Not enough data for training (Less than 100 samples)
# City: 샤자르 - Not enough data for training (Less than 100 samples)
# City: 샤토루 - Not enough data for training (Less than 100 samples)
# City: 세인트토마스 - Not enough data for training (Less than 100 samples)
# City: 소여 - Not enough data for training (Less than 100 samples)
# City: 소치 - Not enough data for training (Less than 100 samples)
# City: 솔트레이크시티 - Not enough data for training (Less than 100 samples)
# City: 쇼나이 - Not enough data for training (Less than 100 samples)
# City: 수라바야 - Not enough data for training (Less than 100 samples)
# City: 쉘야빈스크 - Not enough data for training (Less than 100 samples)
# City: 쉬저우 - Not enough data for training (Less than 100 samples)
# City: 쉬지아쭈앙 - Not enough data for training (Less than 100 samples)
# City: 슈빅 - Not enough data for training (Less than 100 samples)
# City: 슈체친 - Not enough data for training (Less than 100 samples)
# City: 스타방저르 - Not enough data for training (Less than 100 samples)
# City: 스페인 헤타페 - Not enough data for training (Less than 100 samples)
# City: 시닝 - Not enough data for training (Less than 100 samples)
# City: 시라즈 - Not enough data for training (Less than 100 samples)
# City: 시라하마 - Not enough data for training (Less than 100 samples)
# City: 시말린 - Not enough data for training (Less than 100 samples)
# City: 시모지시마 - Not enough data for training (Less than 100 samples)
# City: 시카고 록퍼드 국제공항 - Not enough data for training (Less than 100 samples)
# City: 시하누크빌 - Not enough data for training (Less than 100 samples)
# City: 신추기지 - Not enough data for training (Less than 100 samples)
# City: 아끼다 - Not enough data for training (Less than 100 samples)
# City: 아나디리 - Not enough data for training (Less than 100 samples)
# City: 아다나 - Not enough data for training (Less than 100 samples)
# City: 아디스아바바 - Not enough data for training (Less than 100 samples)
# City: 아메다바드 - Not enough data for training (Less than 100 samples)
# City: 아바칸 - Not enough data for training (Less than 100 samples)
# City: 아사이까와 - Not enough data for training (Less than 100 samples)
# City: 아쉬가바트 - Not enough data for training (Less than 100 samples)
# City: 아스타나 - Not enough data for training (Less than 100 samples)
# City: 아크라코토카 - Not enough data for training (Less than 100 samples)
# City: 아테네 - Not enough data for training (Less than 100 samples)
# City: 아폰소페나 - Not enough data for training (Less than 100 samples)
# City: 악토베 - Not enough data for training (Less than 100 samples)
# City: 안타나리보 - Not enough data for training (Less than 100 samples)
# City: 알 막툼 - Not enough data for training (Less than 100 samples)
# City: 알다프라 - Not enough data for training (Less than 100 samples)
# City: 알아사드공군기지 - Not enough data for training (Less than 100 samples)
# City: 알아인 - Not enough data for training (Less than 100 samples)
# City: 알우데이드 - Not enough data for training (Less than 100 samples)
# City: 암만 - Not enough data for training (Less than 100 samples)
# City: 앙카라 - Not enough data for training (Less than 100 samples)
# City: 애벌론 - Not enough data for training (Less than 100 samples)
# City: 앤더슨공군기지 - Not enough data for training (Less than 100 samples)
# City: 야쿠츠크 - Not enough data for training (Less than 100 samples)
# City: 양저우타이저우 - Not enough data for training (Less than 100 samples)
# City: 에덴버그 - Not enough data for training (Less than 100 samples)
# City: 에드먼튼 - Not enough data for training (Less than 100 samples)
# City: 에버레트 - Not enough data for training (Less than 100 samples)
# City: 에카테린버그 - Not enough data for training (Less than 100 samples)
# City: 엔테베 - Not enough data for training (Less than 100 samples)
# City: 엘도라도 - Not enough data for training (Less than 100 samples)
# City: 엘슨 - Not enough data for training (Less than 100 samples)
# City: 엠벌리공군기지 - Not enough data for training (Less than 100 samples)
# City: 예레반 - Not enough data for training (Less than 100 samples)
# City: 오르도스 - Not enough data for training (Less than 100 samples)
# City: 오브다 공항 - Not enough data for training (Less than 100 samples)
# City: 오산 - Not enough data for training (Less than 100 samples)
# City: 오스코다 - Not enough data for training (Less than 100 samples)
# City: 오스텐드 - Not enough data for training (Less than 100 samples)
# City: 오스틴 - Not enough data for training (Less than 100 samples)
# City: 오크랜드 - Not enough data for training (Less than 100 samples)
# City: 온타리오 - Not enough data for training (Less than 100 samples)
# City: 올스크 - Not enough data for training (Less than 100 samples)
# City: 외레브로 - Not enough data for training (Less than 100 samples)
# City: 요꼬다 - Not enough data for training (Less than 100 samples)
# City: 우돈타니 - Not enough data for training (Less than 100 samples)
# City: 우르겐치 - Not enough data for training (Less than 100 samples)
# City: 우르무치 - Not enough data for training (Less than 100 samples)
# City: 우베 - Not enough data for training (Less than 100 samples)
# City: 우시샤우팡 - Not enough data for training (Less than 100 samples)
# City: 우즈호로드 - Not enough data for training (Less than 100 samples)
# City: 우타파오 - Not enough data for training (Less than 100 samples)
# City: 울란바토르 신공항 - Not enough data for training (Less than 100 samples)
# City: 울란우태 - Not enough data for training (Less than 100 samples)
# City: 울야노브스크 - Not enough data for training (Less than 100 samples)
# City: 워터클루프 - Not enough data for training (Less than 100 samples)
# City: 원산갈마 - Not enough data for training (Less than 100 samples)
# City: 원저우 - Not enough data for training (Less than 100 samples)
# City: 월밍턴 에어파크 - Not enough data for training (Less than 100 samples)
# City: 웨이팡낭위엔 - Not enough data for training (Less than 100 samples)
# City: 위니펙 - Not enough data for training (Less than 100 samples)
# City: 이루크츠크 - Not enough data for training (Less than 100 samples)
# City: 이바라키 - Not enough data for training (Less than 100 samples)
# City: 이슬라마바드 - Not enough data for training (Less than 100 samples)
# City: 이시가키 - Not enough data for training (Less than 100 samples)
# City: 이야쿠니 - Not enough data for training (Less than 100 samples)
# City: 이오지마 - Not enough data for training (Less than 100 samples)
# City: 이우 - Not enough data for training (Less than 100 samples)
# City: 이창 - Not enough data for training (Less than 100 samples)
# City: 인추안 - Not enough data for training (Less than 100 samples)
# City: 인커릭 - Not enough data for training (Less than 100 samples)
# City: 자그레브 - Not enough data for training (Less than 100 samples)
# City: 장가계 - Not enough data for training (Less than 100 samples)
# City: 제너럴 산토스 - Not enough data for training (Less than 100 samples)
# City: 제네바 - Not enough data for training (Less than 100 samples)
# City: 제다 - Not enough data for training (Less than 100 samples)
# City: 제주 - Not enough data for training (Less than 100 samples)
# City: 조호바루 - Not enough data for training (Less than 100 samples)
# City: 주하이 - Not enough data for training (Less than 100 samples)
# City: 지부티 - Not enough data for training (Less than 100 samples)
# City: 진저우 - Not enough data for training (Less than 100 samples)
# City: 진지앙 - Not enough data for training (Less than 100 samples)
# City: 쭌이 씬저우 - Not enough data for training (Less than 100 samples)
# City: 창저우 - Not enough data for training (Less than 100 samples)
# City: 청주 - Not enough data for training (Less than 100 samples)
# City: 첸나이 - Not enough data for training (Less than 100 samples)
# City: 치앙레이 - Not enough data for training (Less than 100 samples)
# City: 치치하얼 - Not enough data for training (Less than 100 samples)
# City: 치타 - Not enough data for training (Less than 100 samples)
# City: 친황다오 - Not enough data for training (Less than 100 samples)
# City: 카라간다 - Not enough data for training (Less than 100 samples)
# City: 카라치 - Not enough data for training (Less than 100 samples)
# City: 카라카스 - Not enough data for training (Less than 100 samples)
# City: 카불 로워시 - Not enough data for training (Less than 100 samples)
# City: 카옌로 샹부 - Not enough data for training (Less than 100 samples)
# City: 카이로 - Not enough data for training (Less than 100 samples)
# City: 카잔 - Not enough data for training (Less than 100 samples)
# City: 카툼 - Not enough data for training (Less than 100 samples)
# City: 칸다하르 - Not enough data for training (Less than 100 samples)
# City: 칸티-만시스크 - Not enough data for training (Less than 100 samples)
# City: 캐언스 - Not enough data for training (Less than 100 samples)
# City: 캘거리 - Not enough data for training (Less than 100 samples)
# City: 캘리포니아 - Not enough data for training (Less than 100 samples)
# City: 캘커타 - Not enough data for training (Less than 100 samples)
# City: 캠프베이슨 - Not enough data for training (Less than 100 samples)
# City: 케프라비크 - Not enough data for training (Less than 100 samples)
# City: 켄사스 - Not enough data for training (Less than 100 samples)
# City: 코펜하겐 - Not enough data for training (Less than 100 samples)
# City: 콜롬보 - Not enough data for training (Less than 100 samples)
# City: 쿠웨이트 - Not enough data for training (Less than 100 samples)
# City: 쿠칭 - Not enough data for training (Less than 100 samples)
# City: 쿠팡엘타리 - Not enough data for training (Less than 100 samples)
# City: 퀴논 - Not enough data for training (Less than 100 samples)
# City: 크라스노얄스크 - Not enough data for training (Less than 100 samples)
# City: 크리스트처칠 - Not enough data for training (Less than 100 samples)
# City: 클래스고 - Not enough data for training (Less than 100 samples)
# City: 키토 마리스칼 수크레 - Not enough data for training (Less than 100 samples)
# City: 킨샤사-은질리 - Not enough data for training (Less than 100 samples)
# City: 킬린포트후드 - Not enough data for training (Less than 100 samples)
# City: 타이난 - Not enough data for training (Less than 100 samples)
# City: 타이유안 - Not enough data for training (Less than 100 samples)
# City: 타크빌라란 - Not enough data for training (Less than 100 samples)
# City: 타히티 - Not enough data for training (Less than 100 samples)
# City: 테키르다 - Not enough data for training (Less than 100 samples)
# City: 테헤란 - Not enough data for training (Less than 100 samples)
# City: 텐푸국제공항 - Not enough data for training (Less than 100 samples)
# City: 템바가푸라 - Not enough data for training (Less than 100 samples)
# City: 토리노 - Not enough data for training (Less than 100 samples)
# City: 토토리 - Not enough data for training (Less than 100 samples)
# City: 톨레도 - Not enough data for training (Less than 100 samples)
# City: 툴루즈 - Not enough data for training (Less than 100 samples)
# City: 튀니즈 - Not enough data for training (Less than 100 samples)
# City: 트라비스 - Not enough data for training (Less than 100 samples)
# City: 트루크멘바시 - Not enough data for training (Less than 100 samples)
# City: 트리에스테 프리올리 베네치아 줄리아 - Not enough data for training (Less than 100 samples)
# City: 트리폴리 - Not enough data for training (Less than 100 samples)
# City: 트빌리시 - Not enough data for training (Less than 100 samples)
# City: 파고헥터 - Not enough data for training (Less than 100 samples)
# City: 파로 - Not enough data for training (Less than 100 samples)
# City: 파리 르부아르 - Not enough data for training (Less than 100 samples)
# City: 파야레버 - Not enough data for training (Less than 100 samples)
# City: 팍세 - Not enough data for training (Less than 100 samples)
# City: 팔레르모 - Not enough data for training (Less than 100 samples)
# City: 퍼스 - Not enough data for training (Less than 100 samples)
# City: 페르가나 - Not enough data for training (Less than 100 samples)
# City: 페르시안걸프 - Not enough data for training (Less than 100 samples)
# City: 페어뱅크스 - Not enough data for training (Less than 100 samples)
# City: 페트로파블로브스키 - Not enough data for training (Less than 100 samples)
# City: 평양 - Not enough data for training (Less than 100 samples)
# City: 포트모레스비 - Not enough data for training (Less than 100 samples)
# City: 포트워스 얼라이언스 - Not enough data for training (Less than 100 samples)
# City: 포트하커트 - Not enough data for training (Less than 100 samples)
# City: 포틀랜드 - Not enough data for training (Less than 100 samples)
# City: 푸에르토프린세사 - Not enough data for training (Less than 100 samples)
# City: 푸조우 - Not enough data for training (Less than 100 samples)
# City: 푸쿡 - Not enough data for training (Less than 100 samples)
# City: 프레스트윅 - Not enough data for training (Less than 100 samples)
# City: 하꼬다데 - Not enough data for training (Less than 100 samples)
# City: 하마나키 - Not enough data for training (Less than 100 samples)
# City: 하사누딘 - Not enough data for training (Less than 100 samples)
# City: 하이데라바드 - Not enough data for training (Less than 100 samples)
# City: 하이커우 - Not enough data for training (Less than 100 samples)
# City: 하이퐁 - Not enough data for training (Less than 100 samples)
# City: 하일라동샨 - Not enough data for training (Less than 100 samples)
# City: 한 - Not enough data for training (Less than 100 samples)
# City: 핫야이 - Not enough data for training (Less than 100 samples)
# City: 헌츠빌 - Not enough data for training (Less than 100 samples)
# City: 헬리팍스 - Not enough data for training (Less than 100 samples)
# City: 호스토멜 - Not enough data for training (Less than 100 samples)
# City: 홍차오 - Not enough data for training (Less than 100 samples)
# City: 화리엔 - Not enough data for training (Less than 100 samples)
# City: 화이안 - Not enough data for training (Less than 100 samples)
# City: 후앙후아 - Not enough data for training (Less than 100 samples)
# City: 후잔드 공항 - Not enough data for training (Less than 100 samples)
# City: 후쿠시마 - Not enough data for training (Less than 100 samples)
# City: 후허하오터 - Not enough data for training (Less than 100 samples)
# City: 휴스턴 - Not enough data for training (Less than 100 samples)
# City: 히캄 - Not enough data for training (Less than 100 samples)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# ...
# Date: 2023-04, Predicted People: 179033.62, Actual People: 129876.00
# Date: 2023-05, Predicted People: 179562.51, Actual People: 123893.00
# Date: 2023-06, Predicted People: 180091.39, Actual People: 123688.00
# Date: 2023-07, Predicted People: 180620.27, Actual People: 147131.00
# City: 홍차오
# Date: 2023-07, Predicted People: 122.06, Actual People: 480.00
# City: 홍차오
# Date: 2023-07, Predicted People: 123.06, Actual People: 480.00
# City: 홍차오
# Date: 2023-07, Predicted People: 122.06, Actual People: 480.00
# City: 홍차오
# Date: 2023-07, Predicted People: 123.06, Actual People: 480.00
# City: 홍차오
# Date: 2023-07, Predicted People: 123.06, Actual People: 480.00
# City: 홍차오
# Date: 2023-07, Predicted People: 123.06, Actual People: 480.00
# City: 홍차오
# Date: 2023-07, Predicted People: 123.06, Actual People: 480.00
# City: 홍차오
# Date: 2023-07, Predicted People: 123.06, Actual People: 480.00
# City: 홍차오
# Date: 2023-07, Predicted People: 123.06, Actual People: 480.00
# City: 홍콩
# Date: 2023-01, Predicted People: 316165.55, Actual People: 96972.00
# Date: 2023-02, Predicted People: 316050.68, Actual People: 86308.00
# Date: 2023-03, Predicted People: 315935.80, Actual People: 123510.00
# Date: 2023-04, Predicted People: 315820.92, Actual People: 134805.00
# Date: 2023-05, Predicted People: 315706.04, Actual People: 137076.00
# Date: 2023-06, Predicted People: 315591.16, Actual People: 133379.00
# Date: 2023-07, Predicted People: 315476.29, Actual People: 144218.00
# City: 휴스턴
# City: 휴스턴
# City: 휴스턴
# City: 휴스턴
# City: 휴스턴
# City: 휴스턴
# City: 휴스턴
# City: 휴스턴
# City: 휴스턴
# City: 휴스턴
# City: 휴스턴
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히로시마
# Date: 2023-07, Predicted People: 1485.51, Actual People: 2376.00
# City: 히캄 - Not enough data for training (Less than 12 samples)
# City: 히캄 - Not enough data for training (Less than 12 samples)
# City: 히캄 - Not enough data for training (Less than 12 samples)
# City: 히캄 - Not enough data for training (Less than 12 samples)
# Mean Accuracy for All Cities: -686.14%

# %%
# !apt-get install -y build-essential python-dev python3-dev
# !pip install --upgrade pystan
# !pip install fbprophet
# Out:
# Collecting fbprophet
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython>=0.22 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (0.29.36)
# Collecting cmdstanpy==0.9.5 (from fbprophet)
#   Using cached cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Requirement already satisfied: pystan>=2.14 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (3.7.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (1.23.5)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (1.5.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (3.7.1)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (2.2.2)
# Requirement already satisfied: holidays>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (0.31)
# Collecting setuptools-git>=1.2 (from fbprophet)
#   Using cached setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (4.66.1)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.1.2->fbprophet) (2023.3)
# Requirement already satisfied: pymeeus<=1,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from convertdate>=2.1.2->fbprophet) (0.5.12)
# Requirement already satisfied: ephem>=3.7.5.3 in /usr/local/lib/python3.10/dist-packages (from LunarCalendar>=0.0.9->fbprophet) (4.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->fbprophet) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->fbprophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->fbprophet) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->fbprophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->fbprophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->fbprophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->fbprophet) (3.1.1)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /usr/local/lib/python3.10/dist-packages (from pystan>=2.14->fbprophet) (3.8.5)
# Requirement already satisfied: clikit<0.7,>=0.6 in /usr/local/lib/python3.10/dist-packages (from pystan>=2.14->fbprophet) (0.6.2)
# Requirement already satisfied: httpstan<4.11,>=4.10 in /usr/local/lib/python3.10/dist-packages (from pystan>=2.14->fbprophet) (4.10.1)
# Requirement already satisfied: pysimdjson<6.0.0,>=5.0.2 in /usr/local/lib/python3.10/dist-packages (from pystan>=2.14->fbprophet) (5.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pystan>=2.14->fbprophet) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->fbprophet) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.3.1)
# Requirement already satisfied: crashtest<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (0.3.1)
# Requirement already satisfied: pastel<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (0.2.1)
# Requirement already satisfied: pylev<2.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (1.4.0)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (1.4.4)
# Requirement already satisfied: marshmallow<4.0,>=3.10 in /usr/local/lib/python3.10/dist-packages (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (3.20.1)
# Requirement already satisfied: webargs<9.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (8.3.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (3.4)
# Building wheels for collected packages: fbprophet
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for fbprophet (setup.py) ... error
#   ERROR: Failed building wheel for fbprophet
#   Running setup.py clean for fbprophet
# Failed to build fbprophet
# ERROR: Could not build wheels for fbprophet, which is required to install pyproject.toml-based projects
