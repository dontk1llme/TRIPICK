# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/세계물가지수.csv")
df
# Out:
#      nation    year price_index
# 0      대한민국  1989.0        41.0
# 1      대한민국  1990.0        44.6
# 2      대한민국  1991.0        48.7
# 3      대한민국  1992.0        51.7
# 4      대한민국  1993.0        54.2
# ...     ...     ...         ...
# 6265   바누아투  2017.0       111.4
# 6266   바누아투  2018.0       114.0
# 6267   바누아투  2019.0       117.1
# 6268   바누아투  2020.0       123.4
# 6269   바누아투  2021.0       126.3
#
# [6270 rows x 3 columns]

# %%
df.rename(columns={"nation":"country"}, inplace=True)
df
# Out:
#      country    year price_index
# 0       대한민국  1989.0        41.0
# 1       대한민국  1990.0        44.6
# 2       대한민국  1991.0        48.7
# 3       대한민국  1992.0        51.7
# 4       대한민국  1993.0        54.2
# ...      ...     ...         ...
# 6265    바누아투  2017.0       111.4
# 6266    바누아투  2018.0       114.0
# 6267    바누아투  2019.0       117.1
# 6268    바누아투  2020.0       123.4
# 6269    바누아투  2021.0       126.3
#
# [6270 rows x 3 columns]

# %%
year = df[['year']].drop_duplicates().astype(int)
year
# Out:
#     year
# 0   1989
# 1   1990
# 2   1991
# 3   1992
# 4   1993
# 5   1994
# 6   1995
# 7   1996
# 8   1997
# 9   1998
# 10  1999
# 11  2000
# 12  2001
# 13  2002
# 14  2003
# 15  2004
# 16  2005
# 17  2006
# 18  2007
# 19  2008
# 20  2009
# 21  2010
# 22  2011
# 23  2012
# 24  2013
# 25  2014
# 26  2015
# 27  2016
# 28  2017
# 29  2018
# 30  2019
# 31  2020
# 32  2021

# %%
df2 = pd.read_csv("./data/소비자_물가지수.csv", encoding="euc-kr").dropna()
df2 = df2.transpose().reset_index(drop=True)
df2 = df2.rename(columns=df2.iloc[0])
df2 = df2.iloc[1:]
df2 = df2.rename(columns={"국가별": 'year'})
df2['year'] = df2['year'].astype(int)
df2 = df2.set_index(keys="year")
df2
# Out:
#        대한민국 아프가니스탄  아르메니아 아제르바이잔    바레인  방글라데시     부탄   브루나이   캄보디아     중국  \
# year
# 1989   41.0      -      -      -   77.7   30.4   30.4   76.4      -   39.2
# 1990   44.6      -      -      -   78.5   32.2   33.4   78.0      -   40.4
# 1991   48.7      -      -    0.0   79.1   34.3   37.5   79.3      -   41.9
# 1992   51.7      -      -    0.0   78.9   35.5   43.5   80.3      -   44.5
# 1993   54.2      -    0.5    0.5   80.9   36.6   48.4   83.7      -   51.0
# 1994   57.6      -   16.0    8.3   81.6   38.6   51.7   85.8   44.9   63.4
# 1995   60.2      -   44.3   42.6   83.8   42.5   56.7   90.9   44.5   74.1
# 1996   63.2      -   52.6   51.0   83.4   43.5   61.6   92.7   47.7   80.2
# 1997   66.0      -   59.9   52.9   85.4   45.9   65.7   94.3   51.5   82.5
# 1998   70.9      -   65.1   52.5   85.1   49.7   72.6   93.9   59.1   81.8
# 1999   71.5      -   65.5   48.0   84.0   52.7   77.5   93.5   61.5   80.7
# ...

# %%
df2 = df2[df2.loc[:, :] != '-']
df2 = df2.astype(float)
df2 = df2.fillna(0)
df2
# Out:
#        대한민국  아프가니스탄  아르메니아  아제르바이잔    바레인  방글라데시     부탄   브루나이   캄보디아     중국  \
# year
# 1989   41.0     0.0    0.0     0.0   77.7   30.4   30.4   76.4    0.0   39.2
# 1990   44.6     0.0    0.0     0.0   78.5   32.2   33.4   78.0    0.0   40.4
# 1991   48.7     0.0    0.0     0.0   79.1   34.3   37.5   79.3    0.0   41.9
# 1992   51.7     0.0    0.0     0.0   78.9   35.5   43.5   80.3    0.0   44.5
# 1993   54.2     0.0    0.5     0.5   80.9   36.6   48.4   83.7    0.0   51.0
# 1994   57.6     0.0   16.0     8.3   81.6   38.6   51.7   85.8   44.9   63.4
# 1995   60.2     0.0   44.3    42.6   83.8   42.5   56.7   90.9   44.5   74.1
# 1996   63.2     0.0   52.6    51.0   83.4   43.5   61.6   92.7   47.7   80.2
# 1997   66.0     0.0   59.9    52.9   85.4   45.9   65.7   94.3   51.5   82.5
# 1998   70.9     0.0   65.1    52.5   85.1   49.7   72.6   93.9   59.1   81.8
# 1999   71.5     0.0   65.5    48.0   84.0   52.7   77.5   93.5   61.5   80.7
# ...

# %%
snp = pd.read_csv("./data/s&p500.csv", encoding="euc-kr")
nifty = pd.read_csv("./data/nifty.csv", encoding="euc-kr")
nasdaq = pd.read_csv("./data/nasdaq.csv", encoding="euc-kr")
kospi = pd.read_csv("./data/kospi.csv", encoding="euc-kr")
hs = pd.read_csv("./data/hangseng.csv", encoding="euc-kr")
ftse = pd.read_csv("./data/ftse.csv", encoding="euc-kr")
dow = pd.read_csv("./data/dowjones.csv", encoding="euc-kr")
dax = pd.read_csv("./data/dax.csv", encoding="euc-kr")
asnp = pd.read_csv("./data/austs&p.csv", encoding="euc-kr")
nikkei = pd.read_csv("./data/nikkei.csv", encoding="euc-kr")

snp = snp.sort_values(by="날짜").reset_index(drop=True)
nifty = nifty.sort_values(by="날짜").reset_index(drop=True)
nasdaq = nasdaq.sort_values(by="날짜").reset_index(drop=True)
kospi = kospi.sort_values(by="날짜").reset_index(drop=True)
hs = hs.sort_values(by="날짜").reset_index(drop=True)
ftse = ftse.sort_values(by="날짜").reset_index(drop=True)
dow = dow.sort_values(by="날짜").reset_index(drop=True)
dax = dax.sort_values(by="날짜").reset_index(drop=True)
asnp = asnp.sort_values(by="날짜").reset_index(drop=True)
nikkei = nikkei.sort_values(by="날짜").reset_index(drop=True)

# %%
snp = snp.iloc[:, :2]
snp = snp.rename(columns = {'종가': 's&p500'})
nifty = nifty.iloc[:, :2]
nifty = nifty.rename(columns = {'종가': 'nifty'})
nasdaq = nasdaq.iloc[:, :2]
nasdaq = nasdaq.rename(columns = {'종가': 'nasdaq'})
kospi = kospi.iloc[:, :2]
kospi = kospi.rename(columns = {'종가': 'kospi'})
hs = hs.iloc[:, :2]
hs = hs.rename(columns = {'종가': 'hangseng'})
ftse = ftse.iloc[:, :2]
ftse = ftse.rename(columns = {'종가': 'ftse'})
dow = dow.iloc[:, :2]
dow = dow.rename(columns = {'종가': 'dowjones'})
dax = dax.iloc[:, :2]
dax = dax.rename(columns = {'종가': 'dax'})
asnp = asnp.iloc[:, :2]
asnp = asnp.rename(columns = {'종가': 'aust_s&p'})
nikkei = nikkei.iloc[:, :2]
nikkei = nikkei.rename(columns = {'종가': 'nikkei'})

# %%
indexes = [snp, nifty, nasdaq, kospi, hs, ftse, dow, dax, asnp, nikkei]


for i in range(1, len(indexes)):
    if(i == 1):
        economic_index = pd.merge(left=snp, right=nifty, how='outer', on='날짜')
    else:
        economic_index = pd.merge(left=economic_index, right=indexes[i], how='outer', on='날짜')

economic_index = economic_index.sort_values("날짜").reset_index(drop=True)
economic_index
# Out:
#               날짜    s&p500      nifty     nasdaq     kospi   hangseng  \
# 0     1999-01-01       NaN      890.8        NaN       NaN        NaN
# 1     1999-01-04  1,228.10      897.8   1,854.39    587.57   9,809.17
# 2     1999-01-05  1,244.80      907.2   1,903.00    598.55   9,891.06
# 3     1999-01-06  1,272.30     928.25   1,963.95    612.36  10,233.80
# 4     1999-01-07  1,269.70      954.7   1,966.35    637.59  10,693.57
# ...          ...       ...        ...        ...       ...        ...
# 6486  2023-08-31  4,507.66  19,253.80  15,501.07  2,556.27  18,382.06
# 6487  2023-09-01  4,515.77  19,435.30  15,490.86  2,563.71        NaN
# 6488  2023-09-04       NaN  19,528.80        NaN  2,584.55  18,852.00
# 6489  2023-09-05       NaN  19,574.05        NaN  2,581.07  18,594.50
# 6490  2023-09-06       NaN        NaN        NaN       NaN        NaN
#
#           ftse   dowjones        dax  aust_s&p     nikkei
# 0          NaN        NaN        NaN       NaN        NaN
# ...

# %%
economic_index['날짜'] = pd.to_datetime(economic_index['날짜'])
for i in indexes:
    economic_index[i.columns[1]] = economic_index[i.columns[1]].str.replace(",", "").astype("float64")

# %%
economic_index["year"] = economic_index['날짜'].dt.year
economic_index
# Out:
#              날짜   s&p500     nifty    nasdaq    kospi  hangseng     ftse  \
# 0    1999-01-01      NaN    890.80       NaN      NaN       NaN      NaN
# 1    1999-01-04  1228.10    897.80   1854.39   587.57   9809.17      NaN
# 2    1999-01-05  1244.80    907.20   1903.00   598.55   9891.06      NaN
# 3    1999-01-06  1272.30    928.25   1963.95   612.36  10233.80      NaN
# 4    1999-01-07  1269.70    954.70   1966.35   637.59  10693.57      NaN
# ...         ...      ...       ...       ...      ...       ...      ...
# 6486 2023-08-31  4507.66  19253.80  15501.07  2556.27  18382.06  7439.13
# 6487 2023-09-01  4515.77  19435.30  15490.86  2563.71       NaN  7464.54
# 6488 2023-09-04      NaN  19528.80       NaN  2584.55  18852.00  7452.76
# 6489 2023-09-05      NaN  19574.05       NaN  2581.07  18594.50      NaN
# 6490 2023-09-06      NaN       NaN       NaN      NaN       NaN      NaN
#
#       dowjones       dax  aust_s&p    nikkei  year
# ...

# %%
year_index_mean = economic_index[["year", "s&p500", "nifty", "nasdaq", "kospi", "hangseng", "ftse", "dowjones", "dax", "aust_s&p", "nikkei"]].groupby(['year'], as_index=False).mean()

# %%
year_index_mean
# Out:
#     year       s&p500         nifty        nasdaq        kospi      hangseng  \
# 0   1999  1327.326190   1211.340354   2363.657817   806.825863  12734.571336
# 1   2000  1427.221825   1417.615400   3599.345317   734.216971  16058.284899
# 2   2001  1194.178226   1121.550000   1750.088185   572.834472  12547.856967
# 3   2002   993.937302   1056.021514   1167.196905   756.978033  10453.831417
# 4   2003   965.225794   1233.705118   1220.370397   679.830000  10291.055363
# 5   2004  1130.647619   1755.868898   1465.350992   832.916305  12918.464297
# 6   2005  1207.228968   2268.910558   1555.705873  1073.577590  14352.592551
# 7   2006  1310.461633   3357.093800   1655.763546  1352.218259  16885.419320
# 8   2007  1477.184542   4571.292369   1943.489920  1712.457886  23196.370870
# 9   2008  1220.042055   4339.113211   1698.948735  1529.494194  20889.575754
# 10  2009   948.046389   4113.960082   1494.792579  1429.038261  18106.037549
# ...

# %%
price_index_table = pd.merge(left=df2, right=year_index_mean, how='inner', on="year")
price_index_table = price_index_table.dropna()
price_index_table = price_index_table.set_index(keys="year")
price_index_table
# Out:
#        대한민국  아프가니스탄  아르메니아  아제르바이잔    바레인  방글라데시     부탄   브루나이   캄보디아     중국  \
# year
# 2001   76.1     0.0   67.0    49.6   82.4   55.0   83.4   95.5   60.6   81.6
# 2002   78.2     0.0   67.8    51.0   82.0   56.8   85.4   93.3   60.8   81.0
# 2003   80.9     0.0   71.0    52.1   83.3   60.0   86.8   93.6   61.3   81.9
# 2004   83.8    63.5   75.9    55.6   85.3   64.6   71.1   94.4   64.0   85.0
# 2005   86.2    71.6   76.4    61.0   87.5   69.2   74.8   95.5   68.2   86.5
# 2006   88.1    76.4   78.6    66.1   89.3   73.8   78.6   95.7   72.2   87.9
# 2007   90.3    83.1   82.1    77.1   92.2   80.6   82.6   96.6   78.5   92.2
# 2008   94.5   105.0   89.4    93.2   95.4   87.7   89.5   98.6   97.4   97.6
# 2009   97.1    97.9   92.4    94.6   98.1   92.5   93.4   99.6   96.2   96.9
# 2010  100.0   100.0  100.0   100.0  100.0  100.0  100.0  100.0  100.0  100.0
# 2011  104.0   111.8  107.7   107.9   99.6  111.4  108.8  100.1  105.5  105.6
# ...

# %%
# !pip install scikit-learn
# !pip install xgboost

# %%
# !pip install keras
# !pip install tensorflow --user

# %%
from sklearn import preprocessing

# %%
price_index_table[['일본']]
# Out:
#          일본
# year
# 2001  101.9
# 2002  101.0
# 2003  100.7
# 2004  100.7
# 2005  100.4
# 2006  100.7
# 2007  100.7
# 2008  102.1
# 2009  100.7
# 2010  100.0
# 2011   99.7
# 2012   99.7
# 2013  100.0
# 2014  102.8
# 2015  103.6
# 2016  103.5
# 2017  104.0
# 2018  105.0
# 2019  105.5
# 2020  105.5
# 2021  105.2

# %%
order = price_index_table.columns[0:189]

plt.rcParams["figure.figsize"] = (15, 6)

for i in order:
    x = price_index_table.index
    plt.subplot(1,2,1)
    plt.plot(x, price_index_table[i], label=i)

plt.ylim([0, 200])
plt.show()

# %%
country = '일본'

scaler1 = preprocessing.MinMaxScaler()
scaler2 = preprocessing.MinMaxScaler()

country_X = price_index_table
country_y = price_index_table[[country]]

scaler_x = scaler1.fit(country_X)
scaler_y = scaler2.fit(country_y)

X_train = scaler_x.transform(country_X[country_X.index<2019])
X_test = scaler_x.transform(country_X[country_X.index>=2019])
y_train = scaler_y.transform(country_y[country_y.index<2019])
y_test = scaler_y.transform(country_y[country_y.index>=2019])

# %% [markdown]
# ### 선형회귀 모델

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

print("가중치(계수, 기울기 파라미터 W) :", model.coef_)
print("편향(절편 파라미터 b) :", model.intercept_)

print("훈련세트 점수: {:.2f}".format( model.score(X_train, y_train) ))
print("테스트세트 점수: {:.2f}".format( model.score(X_test, y_test) ))
# Out:
# 가중치(계수, 기울기 파라미터 W) : [[-1.63437067e-02  1.84917067e-02  7.73140496e-03 -2.05282080e-03
#    1.51957232e-02 -7.61852555e-03  3.10067727e-03  6.12523530e-02
#    5.60350178e-02  7.82912226e-03 -1.14351907e-02 -6.29255352e-02
#   -6.90663864e-03  1.79542873e-02 -1.22676718e-02  4.06255260e-03
#    5.21983450e-03  2.71282101e-03 -3.22387487e-02  2.66533159e-01
#    4.87061159e-02 -3.22524548e-03  3.86534553e-03  9.47403763e-03
#   -1.71577976e-03  4.47581637e-02  1.29058654e-02  1.20853515e-02
#   -2.17565652e-02  2.83622282e-02  1.97168957e-02 -7.85386601e-03
#    2.58859605e-02 -4.38926066e-03  3.53350536e-03  8.39151743e-02
#    5.82265766e-03  1.30688924e-02  9.95684964e-03 -6.17791800e-03
#    3.01387718e-02  4.96423180e-02  1.64861892e-02  1.14886766e-03
#   -2.00118137e-02 -5.32426265e-03 -1.02496715e-02 -9.58664099e-02
#   -4.69788313e-03 -7.24184804e-03  2.66327232e-03  1.27471932e-02
#    1.60888263e-02  1.54491729e-02  6.22794222e-03 -1.00128372e-02
# ...

# %%
y_predicted = model.predict(X_test).reshape([-1, 1])
pd.DataFrame(scaler_y.inverse_transform(y_predicted), columns=['result'])
# Out:
#        result
# 0  104.918758
# 1  105.098361
# 2  105.293061

# %% [markdown]
# ### Random Forest 모델

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=3000, max_depth=7000)
model.fit(X_train, y_train)

print("훈련세트 점수: {:.2f}".format( model.score(X_train, y_train) ))
print("테스트세트 점수: {:.2f}".format( model.score(X_test, y_test) ))

y_predicted = model.predict(X_test).reshape([-1, 1])
pd.DataFrame(scaler_y.inverse_transform(y_predicted), columns=['result'])
# Out:
# c:\Users\SSAFY\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 훈련세트 점수: 0.98
# 테스트세트 점수: -66.22
#        result
# 0  104.448200
# 1  104.290200
# 2  103.990367

# %% [markdown]
# ### DecisionTreeRegressor 모델

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(random_state=0)
model.fit(X_train, y_train)

print("훈련세트 점수: {:.2f}".format( model.score(X_train, y_train) ))
print("테스트세트 점수: {:.2f}".format( model.score(X_test, y_test) ))

y_predicted = model.predict(X_test).reshape([-1, 1])
pd.DataFrame(scaler_y.inverse_transform(y_predicted), columns=['result'])
# Out:
# 훈련세트 점수: 1.00
# 테스트세트 점수: -8.00
#    result
# 0   105.0
# 1   105.0
# 2   105.0

# %% [markdown]
# ### GradientBoostingRegressor 모델

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor(n_estimators=5000, max_depth=5000, random_state=0)
model.fit(X_train, y_train)

print("훈련세트 점수: {:.2f}".format( model.score(X_train, y_train) ))
print("테스트세트 점수: {:.2f}".format( model.score(X_test, y_test) ))

y_predicted = model.predict(X_test).reshape([-1, 1])
pd.DataFrame(scaler_y.inverse_transform(y_predicted), columns=['result'])
# Out:
# c:\Users\SSAFY\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 훈련세트 점수: 1.00
# 테스트세트 점수: -32.50
#        result
# 0  104.697979
# 1  104.542724
# 2  104.528980

# %% [markdown]
# ### XGBRegressor 모델

# %%
from xgboost import XGBRegressor

model = XGBRegressor(n_estimators=5000, max_depth=10000, gamma=0, importance_type='gain', reg_lambda=1, random_state=100)
model.fit(X_train, y_train)

print("훈련세트 점수: {:.2f}".format( model.score(X_train, y_train) ))
print("테스트세트 점수: {:.2f}".format( model.score(X_test, y_test) ))

y_predicted = model.predict(X_test).reshape([-1, 1])
pd.DataFrame(scaler_y.inverse_transform(y_predicted), columns=['result'])
# Out:
# 훈련세트 점수: 1.00
# 테스트세트 점수: -8.31
#        result
# 0  104.992249
# 1  104.992249
# 2  104.992249

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.13.0

# %% [markdown]
# ### Sequential 모델

# %%
model = keras.Sequential()
model.add(layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1))

optimizer = tf.keras.optimizers.RMSprop(0.001)

model.compile(loss="mse", optimizer=optimizer, metrics=['mse', 'mae'])

# %%
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_32 (Dense)            (None, 128)               25728
#
#  dense_33 (Dense)            (None, 64)                8256
#
#  dense_34 (Dense)            (None, 1)                 65
#
# ...
# Total params: 34049 (133.00 KB)
# Trainable params: 34049 (133.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=1000, validation_split=0.2, verbose=0)

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist
# Out:
#          loss       mse       mae  val_loss   val_mse   val_mae  epoch
# 0    0.226726  0.226726  0.410085  0.067367  0.067367  0.220087      0
# 1    0.267826  0.267826  0.426872  0.593472  0.593472  0.750440      1
# 2    0.041871  0.041871  0.146114  0.246020  0.246020  0.471460      2
# 3    0.026192  0.026192  0.129382  0.345640  0.345640  0.566884      3
# 4    0.022542  0.022542  0.115714  0.307148  0.307148  0.532641      4
# ..        ...       ...       ...       ...       ...       ...    ...
# 995  0.000145  0.000145  0.010605  0.035418  0.035418  0.163146    995
# 996  0.000128  0.000128  0.009684  0.030985  0.030985  0.152722    996
# 997  0.000093  0.000093  0.008457  0.036282  0.036282  0.169123    997
# 998  0.000114  0.000114  0.009557  0.027297  0.027297  0.138638    998
# 999  0.000158  0.000158  0.010744  0.039029  0.039029  0.175176    999
#
# [1000 rows x 7 columns]

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure(figsize=(8,12))

  plt.subplot(2,1,1)
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [MPG]')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
#   plt.ylim([0,5])
  plt.legend()

  plt.subplot(2,1,2)
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$MPG^2$]')
  plt.plot(hist['epoch'], hist['mse'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'],
           label = 'Val Error')
  # plt.ylim([0,1])
  plt.legend()
  plt.show()

plot_history(history)

# %%
test_predictions = scaler_y.inverse_transform(model.predict(X_test))

plt.plot(test_predictions)
plt.plot(scaler_y.inverse_transform(y_test))
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
# plt.xlim([0,120])
# plt.ylim([0,120])
# _ = plt.plot([-100, 100], [-100, 100])
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001C61A036FC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 36ms/step
# (-0.1, 3.5065551757812385, 102.05737915039063, 105.66393432617187)

# %%
scaler_y.inverse_transform(model.predict(X_test))
# Out:
# 1/1 [==============================] - 0s 14ms/step
# array([[103.42423],
#        [102.95849],
#        [102.22131]], dtype=float32)

# %%
X_train.shape
# Out:
# (18, 200)

# %% [markdown]
# ### LSTM 모델

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

# %%
price_index_table
# Out:
#        대한민국  아프가니스탄  아르메니아  아제르바이잔    바레인  방글라데시     부탄   브루나이   캄보디아     중국  \
# year
# 2001   76.1     0.0   67.0    49.6   82.4   55.0   83.4   95.5   60.6   81.6
# 2002   78.2     0.0   67.8    51.0   82.0   56.8   85.4   93.3   60.8   81.0
# 2003   80.9     0.0   71.0    52.1   83.3   60.0   86.8   93.6   61.3   81.9
# 2004   83.8    63.5   75.9    55.6   85.3   64.6   71.1   94.4   64.0   85.0
# 2005   86.2    71.6   76.4    61.0   87.5   69.2   74.8   95.5   68.2   86.5
# 2006   88.1    76.4   78.6    66.1   89.3   73.8   78.6   95.7   72.2   87.9
# 2007   90.3    83.1   82.1    77.1   92.2   80.6   82.6   96.6   78.5   92.2
# 2008   94.5   105.0   89.4    93.2   95.4   87.7   89.5   98.6   97.4   97.6
# 2009   97.1    97.9   92.4    94.6   98.1   92.5   93.4   99.6   96.2   96.9
# 2010  100.0   100.0  100.0   100.0  100.0  100.0  100.0  100.0  100.0  100.0
# 2011  104.0   111.8  107.7   107.9   99.6  111.4  108.8  100.1  105.5  105.6
# ...

# %%
import datetime

# %%
years = list(price_index_table.index)

for i in range(len(years)):
    years[i] = datetime.datetime.strptime(str(years[i])+"/01/01", "%Y/%m/%d")

print(type(years[0].date()))

price_index_table.index = years
# Out:
# <class 'datetime.date'>

# %%
price_index_table.index
# Out:
# DatetimeIndex(['2001-01-01', '2002-01-01', '2003-01-01', '2004-01-01',
#                '2005-01-01', '2006-01-01', '2007-01-01', '2008-01-01',
#                '2009-01-01', '2010-01-01', '2011-01-01', '2012-01-01',
#                '2013-01-01', '2014-01-01', '2015-01-01', '2016-01-01',
#                '2017-01-01', '2018-01-01', '2019-01-01', '2020-01-01',
#                '2021-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
price_index_table.index.name = "year"
price_index_table
# Out:
#              대한민국  아프가니스탄  아르메니아  아제르바이잔    바레인  방글라데시     부탄   브루나이   캄보디아  \
# year
# 2001-01-01   76.1     0.0   67.0    49.6   82.4   55.0   83.4   95.5   60.6
# 2002-01-01   78.2     0.0   67.8    51.0   82.0   56.8   85.4   93.3   60.8
# 2003-01-01   80.9     0.0   71.0    52.1   83.3   60.0   86.8   93.6   61.3
# 2004-01-01   83.8    63.5   75.9    55.6   85.3   64.6   71.1   94.4   64.0
# 2005-01-01   86.2    71.6   76.4    61.0   87.5   69.2   74.8   95.5   68.2
# 2006-01-01   88.1    76.4   78.6    66.1   89.3   73.8   78.6   95.7   72.2
# 2007-01-01   90.3    83.1   82.1    77.1   92.2   80.6   82.6   96.6   78.5
# 2008-01-01   94.5   105.0   89.4    93.2   95.4   87.7   89.5   98.6   97.4
# 2009-01-01   97.1    97.9   92.4    94.6   98.1   92.5   93.4   99.6   96.2
# 2010-01-01  100.0   100.0  100.0   100.0  100.0  100.0  100.0  100.0  100.0
# 2011-01-01  104.0   111.8  107.7   107.9   99.6  111.4  108.8  100.1  105.5
# ...

# %%
dates = pd.to_datetime(price_index_table.index)
cols = list(price_index_table)[190:]

# %%
country = '대한민국'
cols.append(country)

country_data = price_index_table[cols].astype(float)

# %%
country_data
# Out:
#                  s&p500         nifty        nasdaq        kospi  \
# year
# 2001-01-01  1194.178226   1121.550000   1750.088185   572.834472
# 2002-01-01   993.937302   1056.021514   1167.196905   756.978033
# 2003-01-01   965.225794   1233.705118   1220.370397   679.830000
# 2004-01-01  1130.647619   1755.868898   1465.350992   832.916305
# 2005-01-01  1207.228968   2268.910558   1555.705873  1073.577590
# 2006-01-01  1310.461633   3357.093800   1655.763546  1352.218259
# 2007-01-01  1477.184542   4571.292369   1943.489920  1712.457886
# 2008-01-01  1220.042055   4339.113211   1698.948735  1529.494194
# 2009-01-01   948.046389   4113.960082   1494.792579  1429.038261
# 2010-01-01  1139.965516   5461.124603   1947.156587  1764.993506
# 2011-01-01  1267.638770   5335.912551   2294.133730  1983.419677
# 2012-01-01  1379.353400   5344.310200   2642.103200  1930.372702
# 2013-01-01  1643.798968   5915.935600   3048.524206  1960.704718
# ...

# %%
scaler = StandardScaler()
scaler = scaler.fit(country_data)
country_data_scaled = scaler.transform(country_data)

# %%
country_data_scaled.shape
# Out:
# (21, 11)

# %%
n_train = int(0.9*country_data_scaled.shape[0])
train_data_scaled = country_data_scaled[0: n_train]
train_dates = dates[0: n_train]

test_data_scaled = country_data_scaled[n_train:]
test_dates = dates[n_train:]

# %%
 # data reformatting for LSTM
pred_days = 1  # prediction period
seq_len = 14   # sequence length = past days for future prediction.
input_dim = 5  # input_dimension = ['Open', 'High', 'Low', 'Close', 'Volume']

trainX = train_data_scaled
trainY = train_data_scaled[:, -1]
testX = test_data_scaled
testY = test_data_scaled[:, -1]

# for i in range(seq_len, n_train-pred_days +1):
#     print(trainX)
#     trainX.append(train_data_scaled[i - seq_len:i, 0:train_data_scaled.shape[1]])
#     trainY.append(train_data_scaled[i + pred_days - 1:i + pred_days, 0])

# for i in range(seq_len, len(test_data_scaled)-pred_days +1):
#     testX.append(test_data_scaled[i - seq_len:i, 0:test_data_scaled.shape[1]])
#     testY.append(test_data_scaled[i + pred_days - 1:i + pred_days, 0])

trainX, trainY = np.array(trainX), np.array(trainY)
testX, testY = np.array(testX), np.array(testY)

# %%
trainX.shape
# Out:
# (18, 11)

# %%
# LSTM model
model = Sequential()
model.add(LSTM(64, input_shape=(trainX.shape[0], trainX.shape[1]), # (seq length, input dimension)
               return_sequences=True))
model.add(LSTM(32, return_sequences=False))
model.add(Dense(trainY.shape[0]))

model.summary()
# Out:
# Model: "sequential_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_56 (LSTM)              (None, 18, 64)            19456
#
#  lstm_57 (LSTM)              (None, 32)                12416
#
#  dense_54 (Dense)            (None, 18)                594
#
# ...
# Total params: 32466 (126.82 KB)
# Trainable params: 32466 (126.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# specify your learning rate
learning_rate = 0.01
# create an Adam optimizer with the specified learning rate
optimizer = Adam(learning_rate=learning_rate)
# compile your model using the custom optimizer
model.compile(optimizer=optimizer, loss='mse')

try:
    model.load_weights('./lstm_weights.h5')
    print("Loaded model weights from disk")
except:
    print("No weights found, training model from scratch")
    # Fit the model
    history = model.fit(trainX, trainY, epochs=30, batch_size=32,
                     verbose=1)
    # Save model weights after training
    model.save_weights('./lstm_weights.h5')

    plt.plot(history.history['loss'], label='Training loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.legend()
    plt.show()
# Out:
# No weights found, training model from scratch
# Epoch 1/30
# C:\Users\SSAFY\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\data\ops\structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[724], line 14
#      12 print("No weights found, training model from scratch")
#      13 # Fit the model
# ---> 14 history = model.fit(trainX, trainY, epochs=30, batch_size=32,
#      15                  verbose=1)
#      16 # Save model weights after training
#      17 model.save_weights('./lstm_weights.h5')
#
# ...

# %%
# prediction
prediction = model.predict(testX)
print(prediction.shape, testY.shape)

# generate array filled with means for prediction
mean_values_pred = np.repeat(scaler.mean_[np.newaxis, :], prediction.shape[0], axis=0)

# substitute predictions into the first column
mean_values_pred[:, 0] = np.squeeze(prediction)

# inverse transform
y_pred = scaler.inverse_transform(mean_values_pred)[:,0]
print(y_pred.shape)

# generate array filled with means for testY
mean_values_testY = np.repeat(scaler.mean_[np.newaxis, :], testY.shape[0], axis=0)

# substitute testY into the first column
mean_values_testY[:, 0] = np.squeeze(testY)

# inverse transform
testY_original = scaler.inverse_transform(mean_values_testY)[:,0]
print(testY_original.shape)

# plotting
plt.figure(figsize=(14, 5))

# plot original 'Open' prices
plt.plot(dates, price_index_table[country].values, color='green', label='Original Open Price')

# plot actual vs predicted
plt.plot(test_dates[seq_len:], testY_original, color='blue', label='Actual Open Price')
plt.plot(test_dates[seq_len:], y_pred, color='red', linestyle='--', label='Predicted Open Price')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Original, Actual and Predicted Open Price')
plt.legend()
plt.show()

# Calculate the start and end indices for the zoomed plot
zoom_start = len(test_dates) - 50
zoom_end = len(test_dates)

# Create the zoomed plot
plt.figure(figsize=(14, 5))

# Adjust the start index for the testY_original and y_pred arrays
adjusted_start = zoom_start - seq_len

plt.plot(test_dates[zoom_start:zoom_end],
         testY_original[adjusted_start:zoom_end - zoom_start + adjusted_start],
         color='blue',
         label='Actual Open Price')

plt.plot(test_dates[zoom_start:zoom_end],
         y_pred[adjusted_start:zoom_end - zoom_start + adjusted_start ],
         color='red',
         linestyle='--',
         label='Predicted Open Price')

plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Zoomed In Actual vs Predicted Open Price')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 33ms/step
# C:\Users\SSAFY\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\data\ops\structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# (1, 1) (1, 1)
# (1,)
# (1,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[665], line 50
#      47 # Adjust the start index for the testY_original and y_pred arrays
#      48 adjusted_start = zoom_start - seq_len
# ---> 50 plt.plot(test_dates[zoom_start:zoom_end],
#      51          testY_original[adjusted_start:zoom_end - zoom_start + adjusted_start],
#      52          color='blue',
#      53          label='Actual Open Price')
# ...

# %%
model.predict(testX)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# C:\Users\SSAFY\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\data\ops\structured_function.py:265: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# array([[1.1386721]], dtype=float32)

# %%
testX
# Out:
# array([[[1.3008766 , 1.35463209, 1.10574184, 0.6538884 , 1.29175179,
#          1.39363743, 1.52267306, 1.20956931, 1.34979108, 1.19563401,
#          1.13278616],
#         [1.65311233, 1.28545789, 1.88950093, 0.83607389, 0.8785703 ,
#          0.35796791, 1.59597833, 1.278367  , 1.03652617, 1.3810207 ,
#          1.17757156]]])
